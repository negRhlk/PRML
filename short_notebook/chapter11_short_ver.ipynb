# %% [markdown]
# # Note
#
# In this chapter, `np.random` is not used except for `np.random.rand()`. <br>
# In `prml.sampling_methods`, this princple is followed.

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from math import gamma 
from scipy.stats import gamma as gamma_dense 

from prml.sampling_methods import (
    BoxMuller,
    GaussSampling,
    InverseFunctionSampling,
    RejectionSampling,
    ImportanceSampling,
    SIR,
    MetropolisHastingsSampling,
    HybridMonteCarlo
)

# %% [markdown]
# # Inverse function sampling

# %%
def p(x,lamda = 1):
    return lamda*np.exp(-lamda*x)

def inv_f(x,lamda=1):
    return -np.log(1 - x)/lamda

# %%
sampler = InverseFunctionSampling(inv_f)
X = sampler.sampling(n = 1000)

fig,ax = plt.subplots(1,1,figsize=(10,7))
ax.hist(X,bins=100,density=True,stacked=True) # for normalize 
x = np.linspace(0,10,100)
ax.plot(x,p(x),label="expo distribution")
ax.set_title("Inverse sampling")
plt.legend()
plt.show()

# %% [markdown]
# # Box Muller

# %%
def gauss(x):
    return 1/(2*np.pi)**0.5*np.exp(-x**2/2)

# %%
bm = BoxMuller()
X = bm.sampling(n=10000)

fig,ax = plt.subplots(1,1,figsize=(10,7))
ax.hist(X,bins=100,density=True,stacked=True) # for normalize 
x = np.linspace(-5,5,100)
ax.plot(x,gauss(x),label="gauss distribution")
ax.set_title("Gaussian by box-muler")
plt.legend()
plt.show()

# %% [markdown]
# ## Gauss sampling

# %%
smp = GaussSampling(D = 2,mu = np.array([5,5]),sigma=np.array([[1,0.7],[0.7,1]]))
X = smp.sampling(n = 10000)

fig,ax = plt.subplots(1,1,figsize=(7,7))
ax.scatter(X[:,0],X[:,1])
ax.set_title("Gaussian by box-muler")
plt.show()

# %% [markdown]
# # Rejection Sampling

# %%
def p_unnormalized(x,a=2,b=2):
    # gamma without norm const
    return x**(a-1)*np.exp(-b*x)

def p(x,a=2,b=2):
    # gamma with norm const
    return gamma_dense.pdf(x,a=a,scale=1/b)

def q(x,b=1,c=0):
    # cauchy 
    return 1/(1 + (x - c)**2/b**2)

def inv_f(x,b=1,c=0):
    # cauchy 
    return b*np.tan(x) + c

# %%
a = 2 
b = (2*a-1)**0.5
c = a-1

isp = InverseFunctionSampling(
    inv_f=lambda x:inv_f(x,b,c),
    a=-np.pi/2,
    b=np.pi/2
)
rsp = RejectionSampling(
    p=lambda x:p(x,a,b),
    q=lambda x:q(x,b,c),
    q_sampler=isp,
    k_lower=0,
    k_upper=10
)
X = rsp.sampling(n=10000)

fig,ax = plt.subplots(1,1,figsize=(10,7))
ax.hist(X,bins=100,density=True,stacked=True) # for normalize 
x = np.linspace(0,8,100)
ax.plot(x,p(x,a,b),label="gamma distribution")
ax.plot(x,rsp.k*q(x,b,c),label="proposal distribution")
ax.set_title("Reject Sampling")
plt.legend()
plt.show()

# %% [markdown]
# # Importance Sampling

# %%
a = 2 
b = (2*a-1)**0.5
c = a-1

isp = InverseFunctionSampling(
    inv_f=lambda x:inv_f(x,b,c),
    a=-np.pi/2,
    b=np.pi/2
)
imsp = ImportanceSampling(
    p=lambda x:p(x,a,b),
    f=lambda x:x,
    q=lambda x:q(x,b,c),
    q_sampler=isp
)
Ex = imsp.calc_expectation(n=10000) 
print("calculated E[x] ",Ex)
print("true E[x] ",a/b)
# Out:
# calculated E[x]  1.1673810744184276
# true E[x]  1.1547005383792517

# %% [markdown]
# # SIR

# %%
a = 2 
b = (2*a-1)**0.5
c = a-1

isp = InverseFunctionSampling(
    inv_f=lambda x:inv_f(x,b,c),
    a=-np.pi/2,
    b=np.pi/2
)
sir = SIR(
    p=lambda x:p(x,a,b),
    q=lambda x:q(x,b,c),
    q_sampler=isp
)
X = sir.sampling(n=10000)

fig,ax = plt.subplots(1,1,figsize=(10,7))
ax.hist(X,bins=100,density=True,stacked=True) # for normalize 
x = np.linspace(0,8,100)
ax.plot(x,p(x,a,b),label="gamma distribution")
ax.set_title("SIR")
plt.legend()
plt.show()

# %% [markdown]
# # Metropolis Hastings

# %%
mu = np.array([0.5,0.5])
sigma = np.array([[1.0,0.7],[0.7,1]])
sigma_inv = np.linalg.inv(sigma)
de = np.linalg.det(sigma)
def p(x):
    return 1/(4*np.pi**2*de)**0.5*np.exp(-0.5*np.dot(x-mu,sigma_inv@(x-mu).reshape(-1,1)))

mh = MetropolisHastingsSampling(p,2,symm=True)
X = mh.sampling(n=10000)

fig,ax = plt.subplots(1,1,figsize=(7,7))
ax.scatter(X[:,0],X[:,1])
ax.set_title("Gaussian by mh")
plt.show()

# %% [markdown]
# # Hybrid Hamiltonian Monte Carlo

# %% [markdown]
# You should choose `eps` so carefully to sample data correctly

# %%
hmc = HybridMonteCarlo(p,2,eps=9e-1)
X = hmc.sampling(n=10000)
fig,ax = plt.subplots(1,1,figsize=(7,7))
ax.scatter(X[:,0],X[:,1])
ax.set_title("Gaussian by HMC")
plt.show()

# %%
## donut 

donut = HybridMonteCarlo(
    p=lambda x:np.exp(-(np.sum(x**2)-5)**2),
    D=2,
    eps=5e-1
)
X = donut.sampling(n=10000)
fig,ax = plt.subplots(1,1,figsize=(7,7))
ax.scatter(X[:,0],X[:,1])
ax.set_title("Donut")
plt.show()
